# %%
import pandas as pd
flipkart_df = pd.read_csv("../data/flipkart_com-ecommerce_sample.csv")
flipkart_df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
flipkart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
# uniq_id                    20000 non-null object
# crawl_timestamp            20000 non-null object
# product_url                20000 non-null object
# product_name               20000 non-null object
# product_category_tree      20000 non-null object
# pid                        20000 non-null object
# retail_price               19922 non-null float64
# discounted_price           19922 non-null float64
# image                      19997 non-null object
# is_FK_Advantage_product    20000 non-null bool
# description                19998 non-null object
# product_rating             20000 non-null object
# overall_rating             20000 non-null object
# brand                      14136 non-null object
# product_specifications     19986 non-null object
# dtypes: bool(1), float64(2), object(12)
# memory usage: 2.2+ MB

# %%
flipkart_df.product_category_tree[0]
# Out:
# '["Clothing >> Women\'s Clothing >> Lingerie, Sleep & Swimwear >> Shorts >> Alisha Shorts >> Alisha Solid Women\'s Cycling Shorts"]'

# %%
flipkart_df.product_category_tree[0]

# %%
flipkart_df.product_specifications[0]
# Out:
# '{"product_specification"=>[{"key"=>"Number of Contents in Sales Package", "value"=>"Pack of 3"}, {"key"=>"Fabric", "value"=>"Cotton Lycra"}, {"key"=>"Type", "value"=>"Cycling Shorts"}, {"key"=>"Pattern", "value"=>"Solid"}, {"key"=>"Ideal For", "value"=>"Women\'s"}, {"value"=>"Gentle Machine Wash in Lukewarm Water, Do Not Bleach"}, {"key"=>"Style Code", "value"=>"ALTHT_3P_21"}, {"value"=>"3 shorts"}]}'

# %%
flipkart_df["product_category"] =flipkart_df["product_category_tree"].str.strip('["').str.strip('"]').str.split('>>').str[0]
print(flipkart_df[["product_category","product_category_tree"]])
# Out:
#                                         product_category  \
# 0                                              Clothing
# 1                                             Furniture
# 2                                              Footwear
# 3                                              Clothing
# 4                                          Pet Supplies
# 5      Eternal Gandhi Super Series Crystal Paper Weig...
# 6                                              Clothing
# 7                                             Furniture
# 8                                              Footwear
# 9                                              Clothing
# 10                                             Footwear
# 11                                             Clothing
# 12                                         Pet Supplies
# 13                                             Clothing
# 14                                    Pens & Stationery
# 15                                             Clothing
# ...

# %%
for i,cat in enumerate(sorted(flipkart_df.product_category.unique()),1):
    print(i,cat)
# Out:
# 1 883 Police Full Sleeve Solid Men's Jacket
# 2 ABEEZ Boys, Men, Girls (Black, Pack of 1)
# 3 ANAND ARCHIES Girls Flats
# 4 ANAND ARCHIES Girls Wedges
# 5 ANASAZI Casual 3/4 Sleeve Solid Women's Top
# 6 ATV Pouch for Acer Liquid Z330 (STEEL BLUE)
# 7 Abhinl Fashion Cotton Printed Semi-stitched Salw...
# 8 Adidas IND PRO THI GUA Thigh Guard (White, Blue,...
# 9 Ajaero Slim Fit Women's Dark Blue Jeans
# 10 Amita Home Furnishing Cotton Floral Single Bedsh...
# 11 Amita Home Furnishing Cotton Printed Single Beds...
# 12 Anuradha Art Stylish Hair Clip (Black)
# 13 Anuradha Art Stylish Hair Clip (Blue)
# 14 Areon Luxurious Fragrance Long Lasting Car,Home,...
# 15 Arial Morris Women Flats
# 16 Asics Gel-Cumulus 17 Running Shoes
# 17 Asics Gel-Kayano 22 Running Shoes
# 18 Attitude Printed Women's Round Neck Black T-Shirt
# 19 Auraa Men's, Women's Solid No Show Socks
# 20 AutoKraftZ Optimum Locking Device For Bajaj Puls...
# 21 Automation & Robotics
# 22 Automotive
# ...

# %%
print("Total no. of Unique Product Categories =" + str(len(flipkart_df.product_category.unique()))) #266
# Out:
# Total no. of Unique Product Categories =266

# %%
# pd.options.display.max_rows
# pd.set_option('display.max_colwidth', -1)
# flip.loc[["c2d766ca982eca8304150849735ffef9"],"product_category_tree"]
