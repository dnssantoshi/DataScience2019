# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
flipkart_df = pd.read_csv("../data/flipkart_com-ecommerce_sample.csv")
flipkart_df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
#
#    retail_price  discounted_price  \
# 0         999.0             379.0
# 1       32157.0           22646.0
# 2         999.0             499.0
# 3         699.0             267.0
# 4         220.0             210.0
#
#                                                image  is_FK_Advantage_product  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...                    False
# 1  ["http://img6a.flixcart.com/image/sofa-bed/j/f...                    False
# 2  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...                    False
# 3  ["http://img5a.flixcart.com/image/short/6/2/h/...                    False
# 4  ["http://img5a.flixcart.com/image/pet-shampoo/...                    False
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2  Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4  Specifications of Sicons All Purpose Arnica Do...  No rating available
#
#         overall_rating         brand  \
# 0  No rating available        Alisha
# 1  No rating available  FabHomeDecor
# 2  No rating available            AW
# 3  No rating available        Alisha
# 4  No rating available        Sicons
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Number of ...
# 1  {"product_specification"=>[{"key"=>"Installati...
# 2  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  {"product_specification"=>[{"key"=>"Number of ...
# 4  {"product_specification"=>[{"key"=>"Pet Type",...

# %% [markdown]
# # uniq id

# %%
#Setting uniq Id as the Index
flipkart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
# uniq_id                    20000 non-null object
# crawl_timestamp            20000 non-null object
# product_url                20000 non-null object
# product_name               20000 non-null object
# product_category_tree      20000 non-null object
# pid                        20000 non-null object
# retail_price               19922 non-null float64
# discounted_price           19922 non-null float64
# image                      19997 non-null object
# is_FK_Advantage_product    20000 non-null bool
# description                19998 non-null object
# product_rating             20000 non-null object
# overall_rating             20000 non-null object
# brand                      14136 non-null object
# product_specifications     19986 non-null object
# dtypes: bool(1), float64(2), object(12)
# memory usage: 2.2+ MB

# %%
import pandas as pd
flipkart_df = pd.read_csv("../data/flipkart_com-ecommerce_sample.csv",index_col=0)
flipkart_df.head()
# Out:
#                                             crawl_timestamp  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                                                         product_url  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  http://www.flipkart.com/alisha-solid-women-s-c...
# 7f7036a6d550aaa89d34c77bd39a5e48  http://www.flipkart.com/fabhomedecor-fabric-do...
# f449ec65dcbc041b6ae5e6a32717d01b  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 0973b37acd0c664e3de26e97e5571454  http://www.flipkart.com/alisha-solid-women-s-c...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                                                            product_name  \
# uniq_id
# c2d766ca982eca8304150849735ffef9    Alisha Solid Women's Cycling Shorts
# 7f7036a6d550aaa89d34c77bd39a5e48    FabHomeDecor Fabric Double Sofa Bed
# f449ec65dcbc041b6ae5e6a32717d01b                             AW Bellies
# 0973b37acd0c664e3de26e97e5571454    Alisha Solid Women's Cycling Shorts
# bc940ea42ee6bef5ac7cea3fb5cfbee7  Sicons All Purpose Arnica Dog Shampoo
#
#                                                               product_category_tree  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  ["Clothing >> Women's Clothing >> Lingerie, Sl...
# 7f7036a6d550aaa89d34c77bd39a5e48  ["Furniture >> Living Room Furniture >> Sofa B...
# f449ec65dcbc041b6ae5e6a32717d01b  ["Footwear >> Women's Footwear >> Ballerinas >...
# 0973b37acd0c664e3de26e97e5571454  ["Clothing >> Women's Clothing >> Lingerie, Sl...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  ["Pet Supplies >> Grooming >> Skin & Coat Care...
#
#                                                pid  retail_price  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  SRTEH2FF9KEDEFGF         999.0
# 7f7036a6d550aaa89d34c77bd39a5e48  SBEEH3QGU7MFYJFY       32157.0
# f449ec65dcbc041b6ae5e6a32717d01b  SHOEH4GRSUBJGZXE         999.0
# 0973b37acd0c664e3de26e97e5571454  SRTEH2F6HUZMQ6SJ         699.0
# bc940ea42ee6bef5ac7cea3fb5cfbee7  PSOEH3ZYDMSYARJ5         220.0
#
#                                   discounted_price  \
# uniq_id
# c2d766ca982eca8304150849735ffef9             379.0
# 7f7036a6d550aaa89d34c77bd39a5e48           22646.0
# f449ec65dcbc041b6ae5e6a32717d01b             499.0
# 0973b37acd0c664e3de26e97e5571454             267.0
# bc940ea42ee6bef5ac7cea3fb5cfbee7             210.0
#
#                                                                               image  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  ["http://img5a.flixcart.com/image/short/u/4/a/...
# 7f7036a6d550aaa89d34c77bd39a5e48  ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# f449ec65dcbc041b6ae5e6a32717d01b  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 0973b37acd0c664e3de26e97e5571454  ["http://img5a.flixcart.com/image/short/6/2/h/...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  ["http://img5a.flixcart.com/image/pet-shampoo/...
#
#                                   is_FK_Advantage_product  \
# uniq_id
# c2d766ca982eca8304150849735ffef9                    False
# 7f7036a6d550aaa89d34c77bd39a5e48                    False
# f449ec65dcbc041b6ae5e6a32717d01b                    False
# 0973b37acd0c664e3de26e97e5571454                    False
# bc940ea42ee6bef5ac7cea3fb5cfbee7                    False
#
#                                                                         description  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  Key Features of Alisha Solid Women's Cycling S...
# 7f7036a6d550aaa89d34c77bd39a5e48  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# f449ec65dcbc041b6ae5e6a32717d01b  Key Features of AW Bellies Sandals Wedges Heel...
# 0973b37acd0c664e3de26e97e5571454  Key Features of Alisha Solid Women's Cycling S...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  Specifications of Sicons All Purpose Arnica Do...
#
#                                        product_rating       overall_rating  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  No rating available  No rating available
# 7f7036a6d550aaa89d34c77bd39a5e48  No rating available  No rating available
# f449ec65dcbc041b6ae5e6a32717d01b  No rating available  No rating available
# 0973b37acd0c664e3de26e97e5571454  No rating available  No rating available
# bc940ea42ee6bef5ac7cea3fb5cfbee7  No rating available  No rating available
#
#                                          brand  \
# uniq_id
# c2d766ca982eca8304150849735ffef9        Alisha
# 7f7036a6d550aaa89d34c77bd39a5e48  FabHomeDecor
# f449ec65dcbc041b6ae5e6a32717d01b            AW
# 0973b37acd0c664e3de26e97e5571454        Alisha
# bc940ea42ee6bef5ac7cea3fb5cfbee7        Sicons
#
#                                                              product_specifications
# uniq_id
# c2d766ca982eca8304150849735ffef9  {"product_specification"=>[{"key"=>"Number of ...
# 7f7036a6d550aaa89d34c77bd39a5e48  {"product_specification"=>[{"key"=>"Installati...
# f449ec65dcbc041b6ae5e6a32717d01b  {"product_specification"=>[{"key"=>"Ideal For"...
# 0973b37acd0c664e3de26e97e5571454  {"product_specification"=>[{"key"=>"Number of ...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  {"product_specification"=>[{"key"=>"Pet Type",...

# %% [markdown]
# # crawl_timestamp

# %%
import pandas as pd
flipkart_df = pd.read_csv("../data/flipkart_com-ecommerce_sample.csv",index_col=0,
                          parse_dates=['crawl_timestamp'])
flipkart_df['crawl_timestamp']=pd.to_datetime(flipkart_df['crawl_timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S'))
flipkart_df.head()
# Out:
#                                      crawl_timestamp  \
# uniq_id
# c2d766ca982eca8304150849735ffef9 2016-03-25 22:59:23
# 7f7036a6d550aaa89d34c77bd39a5e48 2016-03-25 22:59:23
# f449ec65dcbc041b6ae5e6a32717d01b 2016-03-25 22:59:23
# 0973b37acd0c664e3de26e97e5571454 2016-03-25 22:59:23
# bc940ea42ee6bef5ac7cea3fb5cfbee7 2016-03-25 22:59:23
#
#                                                                         product_url  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  http://www.flipkart.com/alisha-solid-women-s-c...
# 7f7036a6d550aaa89d34c77bd39a5e48  http://www.flipkart.com/fabhomedecor-fabric-do...
# f449ec65dcbc041b6ae5e6a32717d01b  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 0973b37acd0c664e3de26e97e5571454  http://www.flipkart.com/alisha-solid-women-s-c...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                                                            product_name  \
# uniq_id
# c2d766ca982eca8304150849735ffef9    Alisha Solid Women's Cycling Shorts
# 7f7036a6d550aaa89d34c77bd39a5e48    FabHomeDecor Fabric Double Sofa Bed
# f449ec65dcbc041b6ae5e6a32717d01b                             AW Bellies
# 0973b37acd0c664e3de26e97e5571454    Alisha Solid Women's Cycling Shorts
# bc940ea42ee6bef5ac7cea3fb5cfbee7  Sicons All Purpose Arnica Dog Shampoo
#
#                                                               product_category_tree  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  ["Clothing >> Women's Clothing >> Lingerie, Sl...
# 7f7036a6d550aaa89d34c77bd39a5e48  ["Furniture >> Living Room Furniture >> Sofa B...
# f449ec65dcbc041b6ae5e6a32717d01b  ["Footwear >> Women's Footwear >> Ballerinas >...
# 0973b37acd0c664e3de26e97e5571454  ["Clothing >> Women's Clothing >> Lingerie, Sl...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  ["Pet Supplies >> Grooming >> Skin & Coat Care...
#
#                                                pid  retail_price  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  SRTEH2FF9KEDEFGF         999.0
# 7f7036a6d550aaa89d34c77bd39a5e48  SBEEH3QGU7MFYJFY       32157.0
# f449ec65dcbc041b6ae5e6a32717d01b  SHOEH4GRSUBJGZXE         999.0
# 0973b37acd0c664e3de26e97e5571454  SRTEH2F6HUZMQ6SJ         699.0
# bc940ea42ee6bef5ac7cea3fb5cfbee7  PSOEH3ZYDMSYARJ5         220.0
#
#                                   discounted_price  \
# uniq_id
# c2d766ca982eca8304150849735ffef9             379.0
# 7f7036a6d550aaa89d34c77bd39a5e48           22646.0
# f449ec65dcbc041b6ae5e6a32717d01b             499.0
# 0973b37acd0c664e3de26e97e5571454             267.0
# bc940ea42ee6bef5ac7cea3fb5cfbee7             210.0
#
#                                                                               image  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  ["http://img5a.flixcart.com/image/short/u/4/a/...
# 7f7036a6d550aaa89d34c77bd39a5e48  ["http://img6a.flixcart.com/image/sofa-bed/j/f...
# f449ec65dcbc041b6ae5e6a32717d01b  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...
# 0973b37acd0c664e3de26e97e5571454  ["http://img5a.flixcart.com/image/short/6/2/h/...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  ["http://img5a.flixcart.com/image/pet-shampoo/...
#
#                                   is_FK_Advantage_product  \
# uniq_id
# c2d766ca982eca8304150849735ffef9                    False
# 7f7036a6d550aaa89d34c77bd39a5e48                    False
# f449ec65dcbc041b6ae5e6a32717d01b                    False
# 0973b37acd0c664e3de26e97e5571454                    False
# bc940ea42ee6bef5ac7cea3fb5cfbee7                    False
#
#                                                                         description  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  Key Features of Alisha Solid Women's Cycling S...
# 7f7036a6d550aaa89d34c77bd39a5e48  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# f449ec65dcbc041b6ae5e6a32717d01b  Key Features of AW Bellies Sandals Wedges Heel...
# 0973b37acd0c664e3de26e97e5571454  Key Features of Alisha Solid Women's Cycling S...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  Specifications of Sicons All Purpose Arnica Do...
#
#                                        product_rating       overall_rating  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  No rating available  No rating available
# 7f7036a6d550aaa89d34c77bd39a5e48  No rating available  No rating available
# f449ec65dcbc041b6ae5e6a32717d01b  No rating available  No rating available
# 0973b37acd0c664e3de26e97e5571454  No rating available  No rating available
# bc940ea42ee6bef5ac7cea3fb5cfbee7  No rating available  No rating available
#
#                                          brand  \
# uniq_id
# c2d766ca982eca8304150849735ffef9        Alisha
# 7f7036a6d550aaa89d34c77bd39a5e48  FabHomeDecor
# f449ec65dcbc041b6ae5e6a32717d01b            AW
# 0973b37acd0c664e3de26e97e5571454        Alisha
# bc940ea42ee6bef5ac7cea3fb5cfbee7        Sicons
#
#                                                              product_specifications
# uniq_id
# c2d766ca982eca8304150849735ffef9  {"product_specification"=>[{"key"=>"Number of ...
# 7f7036a6d550aaa89d34c77bd39a5e48  {"product_specification"=>[{"key"=>"Installati...
# f449ec65dcbc041b6ae5e6a32717d01b  {"product_specification"=>[{"key"=>"Ideal For"...
# 0973b37acd0c664e3de26e97e5571454  {"product_specification"=>[{"key"=>"Number of ...
# bc940ea42ee6bef5ac7cea3fb5cfbee7  {"product_specification"=>[{"key"=>"Pet Type",...

# %%
#import pandas as pd
#dateparse = lambda x: pd.datetime.strftime(x, '%Y-%m-%d %H:%M:%S')
#flipkart_df = pd.read_csv("../data/flipkart_com-ecommerce_sample.csv",index_col=0,dtype={'crawl_timestamp': str},
                          #parse_dates=['crawl_timestamp'],date_parser=dateparse)
#flipkart_df['crawl_timestamp']=pd.to_datetime(flipkart_df['crawl_timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S'))
#flipkart_df.head()

# %%
flipkart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, c2d766ca982eca8304150849735ffef9 to cb4fa87a874f715fff567f7b7b3be79c
# Data columns (total 14 columns):
# crawl_timestamp            20000 non-null datetime64[ns]
# product_url                20000 non-null object
# product_name               20000 non-null object
# product_category_tree      20000 non-null object
# pid                        20000 non-null object
# retail_price               19922 non-null float64
# discounted_price           19922 non-null float64
# image                      19997 non-null object
# is_FK_Advantage_product    20000 non-null bool
# description                19998 non-null object
# product_rating             20000 non-null object
# overall_rating             20000 non-null object
# brand                      14136 non-null object
# product_specifications     19986 non-null object
# dtypes: bool(1), datetime64[ns](1), float64(2), object(10)
# memory usage: 2.2+ MB

# %% [markdown]
# # product_url
#
# *No clean up needed - No nulls either*

# %%
len(flipkart_df.product_url.unique())
# Out:
# 20000

# %% [markdown]
# # product_name
#
# *No clean up needed - No nulls either*

# %%
flipkart_df.product_name.unique()[:5]
# Out:
# array(["Alisha Solid Women's Cycling Shorts",
#        'FabHomeDecor Fabric Double Sofa Bed', 'AW Bellies',
#        'Sicons All Purpose Arnica Dog Shampoo',
#        'Eternal Gandhi Super Series Crystal Paper Weights  with Silver Finish'],
#       dtype=object)

# %%
flipkart_df.product_name=flipkart_df.product_name.astype('category')

# %%
len(flipkart_df.product_name.unique())
# Out:
# 12676

# %%
flipkart_df.product_name[0]
# Out:
# "Alisha Solid Women's Cycling Shorts"

# %% [markdown]
# # product_category_tree
#
# *The PREDICTOR variable*

# %%
flipkart_df.product_category_tree[0] #Sample value
# Out:
# '["Clothing >> Women\'s Clothing >> Lingerie, Sleep & Swimwear >> Shorts >> Alisha Shorts >> Alisha Solid Women\'s Cycling Shorts"]'

# %%
flipkart_df.product_category_tree=flipkart_df.product_category_tree.str.replace('[','').str.replace(']','').str.split('>>').str[0].str.strip('\"').astype('category')

# %%
flipkart_df.product_category_tree.drop_duplicates().shape #retrieves unique categories as a series
# Out:
# (266,)

# %%
flipkart_df.product_category_tree.head(2)
# Out:
# uniq_id
# c2d766ca982eca8304150849735ffef9     Clothing
# 7f7036a6d550aaa89d34c77bd39a5e48    Furniture
# Name: product_category_tree, dtype: category
# Categories (266, object): [883 Police Full Sleeve Solid Men's Jacket, ABEEZ Boys, Men, Girls (Black, Pack of 1), ANAND ARCHIES Girls Flats, ANAND ARCHIES Girls Wedges, ..., soie Fashion Women's Full Coverage Bra, soie Fashion Women's Sports Bra, tadd Men's, Women's Ankle Length Socks, xy decor Cotton Sofa Cover (white Pack of 6)]

# %% [markdown]
# # pid

# %%
flipkart_df['pid'][0:5]
# Out:
# uniq_id
# c2d766ca982eca8304150849735ffef9    SRTEH2FF9KEDEFGF
# 7f7036a6d550aaa89d34c77bd39a5e48    SBEEH3QGU7MFYJFY
# f449ec65dcbc041b6ae5e6a32717d01b    SHOEH4GRSUBJGZXE
# 0973b37acd0c664e3de26e97e5571454    SRTEH2F6HUZMQ6SJ
# bc940ea42ee6bef5ac7cea3fb5cfbee7    PSOEH3ZYDMSYARJ5
# Name: pid, dtype: object

# %%
my_series=flipkart_df['pid'].value_counts() > 1

# %%
my_series= flipkart_df.groupby('pid')['pid'].count() > 1
print(type(my_series))
my_series.sort_values()[-5:]
# Out:
# <class 'pandas.core.series.Series'>
# pid
# DRPEHYHNCZXNYFZH    False
# DSEEHETVWRX9FZDT    False
# YSPEGGA5JKZFHP97    False
# JEAEGE8Q8GXYFTGU     True
# ACCEJ6TESY7AFT5W     True
# Name: pid, dtype: bool

# %%
flipkart_df[flipkart_df['pid'].isin(['JEAEGE8Q8GXYFTGU','ACCEJ6TESY7AFT5W'])].sort_values(by='pid')
# Out:
#                                      crawl_timestamp  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877 2016-06-10 22:31:19
# 82f424a90d630acc188fcf267160a1fe 2016-06-16 06:18:58
# f4e20863651ea54537388f1cd77a8776 2016-05-12 14:18:51
# 2867c80d88e3693c883463e6358e6cc5 2016-05-10 11:57:25
#
#                                                                         product_url  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877  http://www.flipkart.com/hako-60w-magsafe-lapto...
# 82f424a90d630acc188fcf267160a1fe  http://www.flipkart.com/hako-60w-magsafe1-lapt...
# f4e20863651ea54537388f1cd77a8776  http://www.flipkart.com/timberlake-slim-fit-wo...
# 2867c80d88e3693c883463e6358e6cc5  http://www.flipkart.com/timberlake-slim-fit-wo...
#
#                                                                        product_name  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877  Hako 60W Magsafe Laptop Charger For APPLE MacB...
# 82f424a90d630acc188fcf267160a1fe  Hako 60W Magsafe1 Laptop Charger For APPLE Mac...
# f4e20863651ea54537388f1cd77a8776         TIMBERLAKE Slim Fit Fit Women's Blue Jeans
# 2867c80d88e3693c883463e6358e6cc5         TIMBERLAKE Slim Fit Fit Women's Blue Jeans
#
#                                  product_category_tree               pid  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877            Computers   ACCEJ6TESY7AFT5W
# 82f424a90d630acc188fcf267160a1fe            Computers   ACCEJ6TESY7AFT5W
# f4e20863651ea54537388f1cd77a8776             Clothing   JEAEGE8Q8GXYFTGU
# 2867c80d88e3693c883463e6358e6cc5             Clothing   JEAEGE8Q8GXYFTGU
#
#                                   retail_price  discounted_price  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877        2399.0            1799.0
# 82f424a90d630acc188fcf267160a1fe        2399.0            1799.0
# f4e20863651ea54537388f1cd77a8776        1499.0            1099.0
# 2867c80d88e3693c883463e6358e6cc5        1499.0            1099.0
#
#                                                                               image  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877  ["http://img6a.flixcart.com/image/laptop-adapt...
# 82f424a90d630acc188fcf267160a1fe  ["http://img6a.flixcart.com/image/laptop-adapt...
# f4e20863651ea54537388f1cd77a8776  ["http://img5a.flixcart.com/image/jean/g/p/z/a...
# 2867c80d88e3693c883463e6358e6cc5  ["http://img5a.flixcart.com/image/jean/g/p/z/a...
#
#                                   is_FK_Advantage_product  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877                    False
# 82f424a90d630acc188fcf267160a1fe                    False
# f4e20863651ea54537388f1cd77a8776                    False
# 2867c80d88e3693c883463e6358e6cc5                    False
#
#                                                                         description  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877  Key Features of Hako 60W Magsafe Laptop Charge...
# 82f424a90d630acc188fcf267160a1fe  Key Features of Hako 60W Magsafe1 Laptop Charg...
# f4e20863651ea54537388f1cd77a8776  Key Features of TIMBERLAKE Slim Fit Fit Women'...
# 2867c80d88e3693c883463e6358e6cc5  Key Features of TIMBERLAKE Slim Fit Fit Women'...
#
#                                        product_rating       overall_rating  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877  No rating available  No rating available
# 82f424a90d630acc188fcf267160a1fe  No rating available  No rating available
# f4e20863651ea54537388f1cd77a8776  No rating available  No rating available
# 2867c80d88e3693c883463e6358e6cc5  No rating available  No rating available
#
#                                        brand  \
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877        Hako
# 82f424a90d630acc188fcf267160a1fe        Hako
# f4e20863651ea54537388f1cd77a8776  TIMBERLAKE
# 2867c80d88e3693c883463e6358e6cc5  TIMBERLAKE
#
#                                                              product_specifications
# uniq_id
# 3ddf7a0f5669f84751a36469af11b877  {"product_specification"=>[{"key"=>"Brand", "v...
# 82f424a90d630acc188fcf267160a1fe  {"product_specification"=>[{"key"=>"Brand", "v...
# f4e20863651ea54537388f1cd77a8776  {"product_specification"=>[{"key"=>"Brand Colo...
# 2867c80d88e3693c883463e6358e6cc5  {"product_specification"=>[{"key"=>"Brand Colo...

# %%
flipkart_df = flipkart_df.drop_duplicates(subset='pid',keep='first') # Removes the above identified 
    # duplicate values based on 'pid'
flipkart_df.count() # Removed two duplicate pid rows
# Out:
# crawl_timestamp            19998
# product_url                19998
# product_name               19998
# product_category_tree      19998
# pid                        19998
# retail_price               19920
# discounted_price           19920
# image                      19995
# is_FK_Advantage_product    19998
# description                19996
# product_rating             19998
# overall_rating             19998
# brand                      14134
# product_specifications     19984
# dtype: int64

# %% [markdown]
# # retail_price

# %%
flipkart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19998 entries, c2d766ca982eca8304150849735ffef9 to cb4fa87a874f715fff567f7b7b3be79c
# Data columns (total 14 columns):
# crawl_timestamp            19998 non-null datetime64[ns]
# product_url                19998 non-null object
# product_name               19998 non-null category
# product_category_tree      19998 non-null category
# pid                        19998 non-null object
# retail_price               19920 non-null float64
# discounted_price           19920 non-null float64
# image                      19995 non-null object
# is_FK_Advantage_product    19998 non-null bool
# description                19996 non-null object
# product_rating             19998 non-null object
# overall_rating             19998 non-null object
# brand                      14134 non-null object
# product_specifications     19984 non-null object
# dtypes: bool(1), category(2), datetime64[ns](1), float64(2), object(8)
# memory usage: 2.7+ MB

# %%
len(sorted(flipkart_df.retail_price,reverse=True))
# Out:
# 19998

# %%
flipkart_df[flipkart_df['retail_price'].isnull()].head(2)
# Out:
#                                      crawl_timestamp  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f 2016-03-25 22:59:23
# ea98a65ad1e1b8688eddf89fbc7b3e27 2016-03-25 22:59:23
#
#                                                                         product_url  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  http://www.flipkart.com/sicons-all-purpose-tea...
# ea98a65ad1e1b8688eddf89fbc7b3e27  http://www.flipkart.com/alisha-solid-women-s-c...
#
#                                                              product_name  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  Sicons All Purpose Tea Tree Dog Shampoo
# ea98a65ad1e1b8688eddf89fbc7b3e27      Alisha Solid Women's Cycling Shorts
#
#                                  product_category_tree               pid  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f         Pet Supplies   PSOEH3ZYYFETGCCD
# ea98a65ad1e1b8688eddf89fbc7b3e27             Clothing   SRTEH2FD3ANFFMHP
#
#                                   retail_price  discounted_price  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f           NaN               NaN
# ea98a65ad1e1b8688eddf89fbc7b3e27           NaN               NaN
#
#                                                                               image  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  ["http://img6a.flixcart.com/image/pet-shampoo/...
# ea98a65ad1e1b8688eddf89fbc7b3e27  ["http://img6a.flixcart.com/image/short/m/g/y/...
#
#                                   is_FK_Advantage_product  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f                    False
# ea98a65ad1e1b8688eddf89fbc7b3e27                    False
#
#                                                                         description  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  Specifications of Sicons All Purpose Tea Tree ...
# ea98a65ad1e1b8688eddf89fbc7b3e27  Alisha Solid Women's Cycling Shorts - Buy Blac...
#
#                                        product_rating       overall_rating  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  No rating available  No rating available
# ea98a65ad1e1b8688eddf89fbc7b3e27  No rating available  No rating available
#
#                                    brand  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  Sicons
# ea98a65ad1e1b8688eddf89fbc7b3e27  Alisha
#
#                                                              product_specifications
# uniq_id
# c29af37837afcaf44b779eca7c19295f  {"product_specification"=>[{"key"=>"Pet Type",...
# ea98a65ad1e1b8688eddf89fbc7b3e27                                                NaN

# %% [markdown]
# # discounted_price

# %%
flipkart_df[flipkart_df['discounted_price'].isnull()].head(1)
# Out:
#                                      crawl_timestamp  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f 2016-03-25 22:59:23
#
#                                                                         product_url  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  http://www.flipkart.com/sicons-all-purpose-tea...
#
#                                                              product_name  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  Sicons All Purpose Tea Tree Dog Shampoo
#
#                                  product_category_tree               pid  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f         Pet Supplies   PSOEH3ZYYFETGCCD
#
#                                   retail_price  discounted_price  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f           NaN               NaN
#
#                                                                               image  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  ["http://img6a.flixcart.com/image/pet-shampoo/...
#
#                                   is_FK_Advantage_product  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f                    False
#
#                                                                         description  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  Specifications of Sicons All Purpose Tea Tree ...
#
#                                        product_rating       overall_rating  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  No rating available  No rating available
#
#                                    brand  \
# uniq_id
# c29af37837afcaf44b779eca7c19295f  Sicons
#
#                                                              product_specifications
# uniq_id
# c29af37837afcaf44b779eca7c19295f  {"product_specification"=>[{"key"=>"Pet Type",...

# %% [markdown]
# # image

# %%
flipkart_df['image'].str.split('"').str[1][:6]
# Out:
# uniq_id
# c2d766ca982eca8304150849735ffef9    http://img5a.flixcart.com/image/short/u/4/a/al...
# 7f7036a6d550aaa89d34c77bd39a5e48    http://img6a.flixcart.com/image/sofa-bed/j/f/y...
# f449ec65dcbc041b6ae5e6a32717d01b    http://img5a.flixcart.com/image/shoe/7/z/z/red...
# 0973b37acd0c664e3de26e97e5571454    http://img5a.flixcart.com/image/short/6/2/h/al...
# bc940ea42ee6bef5ac7cea3fb5cfbee7    http://img5a.flixcart.com/image/pet-shampoo/r/...
# c2a17313954882c1dba461863e98adf2    http://img5a.flixcart.com/image/paper-weight/u...
# Name: image, dtype: object

# %% [markdown]
# # is_FK_Advantage_product

# %%
flipkart_df[flipkart_df.is_FK_Advantage_product.isnull()] # no Null entries
# Out:
# Empty DataFrame
# Columns: [crawl_timestamp, product_url, product_name, product_category_tree, pid, retail_price, discounted_price, image, is_FK_Advantage_product, description, product_rating, overall_rating, brand, product_specifications]
# Index: []

# %%
flipkart_df.shape
# Out:
# (19998, 14)

# %% [markdown]
# # description
# # How to deal with null values ??

# %%
flipkart_df[flipkart_df.description.isnull()] # Has 2 NaN rows #
# Out:
#                                      crawl_timestamp  \
# uniq_id
# ebd53621ef37807f0d60dbde419a1189 2016-01-06 18:20:45
# 5c753808021920c85f3a4852f1c58c40 2015-12-20 08:26:17
#
#                                                                         product_url  \
# uniq_id
# ebd53621ef37807f0d60dbde419a1189  http://www.flipkart.com/ozel-studio-casual-sle...
# 5c753808021920c85f3a4852f1c58c40  http://www.flipkart.com/amore-abstract-cushion...
#
#                                                                        product_name  \
# uniq_id
# ebd53621ef37807f0d60dbde419a1189  Ozel Studio Casual Sleeveless Printed Women's Top
# 5c753808021920c85f3a4852f1c58c40                      Amore Abstract Cushions Cover
#
#                                  product_category_tree               pid  \
# uniq_id
# ebd53621ef37807f0d60dbde419a1189             Clothing   TOPEYV38KYVJKM54
# 5c753808021920c85f3a4852f1c58c40      Home Furnishing   CPCE2ZME2P7BMJFB
#
#                                   retail_price  discounted_price  \
# uniq_id
# ebd53621ef37807f0d60dbde419a1189        1290.0             645.0
# 5c753808021920c85f3a4852f1c58c40         499.0             299.0
#
#                                                                               image  \
# uniq_id
# ebd53621ef37807f0d60dbde419a1189  ["http://img6a.flixcart.com/image/top/p/z/p/t-...
# 5c753808021920c85f3a4852f1c58c40  ["http://img6a.flixcart.com/image/cushion-pill...
#
#                                   is_FK_Advantage_product description  \
# uniq_id
# ebd53621ef37807f0d60dbde419a1189                    False         NaN
# 5c753808021920c85f3a4852f1c58c40                    False         NaN
#
#                                        product_rating       overall_rating  \
# uniq_id
# ebd53621ef37807f0d60dbde419a1189  No rating available  No rating available
# 5c753808021920c85f3a4852f1c58c40  No rating available  No rating available
#
#                                   brand  \
# uniq_id
# ebd53621ef37807f0d60dbde419a1189    NaN
# 5c753808021920c85f3a4852f1c58c40  Amore
#
#                                                              product_specifications
# uniq_id
# ebd53621ef37807f0d60dbde419a1189  {"product_specification"=>[{"key"=>"Ideal For"...
# 5c753808021920c85f3a4852f1c58c40  {"product_specification"=>[{"key"=>"Brand", "v...

# %%
flipkart_df.groupby('product_category_tree')['description'].count().sort_values(ascending=False)
# Out:
# product_category_tree
# Clothing                                                6196
# Jewellery                                               3531
# Footwear                                                1227
# Mobiles & Accessories                                   1099
# Automotive                                              1012
# Home Decor & Festive Needs                               929
# Beauty and Personal Care                                 710
# Home Furnishing                                          699
# Kitchen & Dining                                         647
# Computers                                                577
# Watches                                                  530
# Baby Care                                                483
# Tools & Hardware                                         391
# Toys & School Supplies                                   330
# Pens & Stationery                                        313
# Bags, Wallets & Belts                                    265
# Furniture                                                180
# Sports & Fitness                                         166
# Cameras & Accessories                                     82
# Home Improvement                                          81
# Health & Personal Care Appliances                         43
# Gaming                                                    35
# Sunglasses                                                35
# Pet Supplies                                              30
# Home & Kitchen                                            24
# Home Entertainment                                        19
# eBooks                                                    15
# Eyewear                                                   10
# Clovia Women's Full Coverage Bra                           9
# Vishudh Printed Women's Straight Kurta                     8
#                                                         ...
# Power Smart Quick Charging Pack For PAN CGR-D28 ...        1
# Power Smart Quick Charging Pack For PAN CGR-DU-2...        1
# Prime Printed 8 Seater Table Cover (Multicolor, ...        1
# PrivateLifes MasterPiece Women's Push-up Bra               1
# Shonaya Printed Bhagalpuri Art Silk Sari                   1
# Selfcare Women's Thong Panty (Pack of 3)                   1
# Samprada Modern art Tapestry (Black, Pink)                 1
# SUPERMOD Men's Brief                                       1
# SRPC BAOER STARWALKER EXECUTIVE ROLLERBALL Pen G...        1
# SMART TRADERS Women Wedges                                 1
# SMART TRADERS Women Flats                                  1
# SMART TRADERS Girls Bellies                                1
# SMART DENIM Solid Women's White Denim Shorts               1
# SJ Comet Zoom DPSI Binoculars (30 mm, Black)               1
# SJ Bushnell 122/1000M Binoculars (36 mm, Black)            1
# SJ Barstel 56m / 1000m Binoculars (30 mm, Black)           1
# SHOPOJ Yellow Paper Sky Lantern (80 cm X 34 cm, ...        1
# SHOPOJ White Paper Sky Lantern (80 cm X 34 cm, P...        1
# SHOPOJ Purple Paper Sky Lantern (80 cm X 34 cm, ...        1
# SHOPOJ Multicolor Paper Sky Lantern (80 cm X 34 ...        1
# SAY UV Sterilizer Solid Filter Cartridge (0, Pac...        1
# SAY Thread Wounded Candle 10\" Set of 4 pcs Solid...       1
# Ruhi's Creations Cotton Floral King sized Double...        1
# Ruhi's Creations Cotton Cartoon King sized Doubl...        1
# Royal Seal Creations 40 ST COLOR Silver Zircon N...        1
# Remax Rm-10000 Remax Vanguard 10000mah 10000 mAh...        1
# Rasav Jewels Yellow Gold Diamond 18 K Ring                 1
# RajeshFashion Women's Leggings                             1
# REMSON INDIA Women Flats                                   1
# 883 Police Full Sleeve Solid Men's Jacket                  1
# Name: description, Length: 266, dtype: int64

# %% [markdown]
# # Approach - 1

# %% [markdown]
# # product_rating

# %%
 # Re-iterate the read_csv import with na_values in dict form
flipkart_df.product_rating=pd.to_numeric(flipkart_df['product_rating'],errors='coerce')
flipkart_df.product_rating.unique()
# Out:
# array([nan, 5. , 3. , 3.6, 3.5, 4.4, 4. , 1. , 2.3, 4.8, 2.7, 4.5, 2.4,
#        3.2, 4.7, 2. , 3.3, 4.3, 3.8, 4.2, 3.7, 3.9, 2.5, 3.1, 4.1, 3.4,
#        4.6, 1.5, 2.8, 2.9, 4.9, 2.2, 2.6, 1.3, 1.7, 1.8])

# %% [markdown]
# # overall_rating

# %%
flipkart_df.overall_rating =pd.to_numeric(flipkart_df['overall_rating'],errors='coerce')
flipkart_df.overall_rating.unique()
# Out:
# array([nan, 5. , 3. , 3.6, 3.5, 4.4, 4. , 1. , 2.3, 4.8, 2.7, 4.5, 2.4,
#        3.2, 4.7, 2. , 3.3, 4.3, 3.8, 4.2, 3.7, 3.9, 2.5, 3.1, 4.1, 3.4,
#        4.6, 1.5, 2.8, 2.9, 4.9, 2.2, 2.6, 1.3, 1.7, 1.8])

# %% [markdown]
# # Approach - 2

# %% [markdown]
# *read_csv import to handle nulls*
#
# na_values={'product_rating':'No rating available','overall_rating':'No rating available'})

# %%
flipkart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19998 entries, c2d766ca982eca8304150849735ffef9 to cb4fa87a874f715fff567f7b7b3be79c
# Data columns (total 14 columns):
# crawl_timestamp            19998 non-null datetime64[ns]
# product_url                19998 non-null object
# product_name               19998 non-null category
# product_category_tree      19998 non-null category
# pid                        19998 non-null object
# retail_price               19920 non-null float64
# discounted_price           19920 non-null float64
# image                      19995 non-null object
# is_FK_Advantage_product    19998 non-null bool
# description                19996 non-null object
# product_rating             1849 non-null float64
# overall_rating             1849 non-null float64
# brand                      14134 non-null object
# product_specifications     19984 non-null object
# dtypes: bool(1), category(2), datetime64[ns](1), float64(4), object(6)
# memory usage: 2.7+ MB

# %% [markdown]
# # brand

# %%
flipkart_df[flipkart_df.brand.isnull()].head()
# Out:
#                                      crawl_timestamp  \
# uniq_id
# bb41283056536d7af11e994ba4f9db81 2016-01-03 20:56:50
# ea91e47cac68b132887d7fc1175e91c2 2016-01-03 20:56:50
# bec784ef794cf596dbe2cbbaf5427ef0 2016-01-03 20:56:50
# 171e0bcea390c17fd70e3ffa6c2cd187 2016-01-03 20:56:50
# a60ebb7803c6a31795de3f8949cb6f98 2016-01-03 20:56:50
#
#                                                                         product_url  \
# uniq_id
# bb41283056536d7af11e994ba4f9db81  http://www.flipkart.com/glus-wedding-lingerie-...
# ea91e47cac68b132887d7fc1175e91c2  http://www.flipkart.com/veelys-shiny-white-qua...
# bec784ef794cf596dbe2cbbaf5427ef0  http://www.flipkart.com/bulaky-vanity-case-jew...
# 171e0bcea390c17fd70e3ffa6c2cd187  http://www.flipkart.com/fdt-women-s-leggings/p...
# a60ebb7803c6a31795de3f8949cb6f98  http://www.flipkart.com/madcaps-c38gr30-men-s-...
#
#                                                                        product_name  \
# uniq_id
# bb41283056536d7af11e994ba4f9db81                          Glus Wedding Lingerie Set
# ea91e47cac68b132887d7fc1175e91c2  Veelys Shiny White Quad Roller Skates - Size 4...
# bec784ef794cf596dbe2cbbaf5427ef0           Bulaky vanity case Jewellery Vanity Case
# 171e0bcea390c17fd70e3ffa6c2cd187                               FDT Women's Leggings
# a60ebb7803c6a31795de3f8949cb6f98                       Madcaps C38GR30 Men's Cargos
#
#                                       product_category_tree               pid  \
# uniq_id
# bb41283056536d7af11e994ba4f9db81                  Clothing   LINE92U9KGZG25AY
# ea91e47cac68b132887d7fc1175e91c2          Sports & Fitness   SKTEC88WSNYJKWY7
# bec784ef794cf596dbe2cbbaf5427ef0  Beauty and Personal Care   VANDZY4YZFPEG85T
# 171e0bcea390c17fd70e3ffa6c2cd187                  Clothing   LJGEB2KMCMMHHFC7
# a60ebb7803c6a31795de3f8949cb6f98                  Clothing   CRGE6A53UX7CJMXX
#
#                                   retail_price  discounted_price  \
# uniq_id
# bb41283056536d7af11e994ba4f9db81        1299.0             699.0
# ea91e47cac68b132887d7fc1175e91c2        3199.0            2499.0
# bec784ef794cf596dbe2cbbaf5427ef0         499.0             390.0
# 171e0bcea390c17fd70e3ffa6c2cd187         699.0             309.0
# a60ebb7803c6a31795de3f8949cb6f98        2199.0            1699.0
#
#                                                                               image  \
# uniq_id
# bb41283056536d7af11e994ba4f9db81  ["http://img5a.flixcart.com/image/lingerie-set...
# ea91e47cac68b132887d7fc1175e91c2  ["http://img6a.flixcart.com/image/skate/w/y/7/...
# bec784ef794cf596dbe2cbbaf5427ef0  ["http://img6a.flixcart.com/image/vanity-box/8...
# 171e0bcea390c17fd70e3ffa6c2cd187  ["http://img6a.flixcart.com/image/legging-jegg...
# a60ebb7803c6a31795de3f8949cb6f98  ["http://img5a.flixcart.com/image/cargo/n/g/h/...
#
#                                   is_FK_Advantage_product  \
# uniq_id
# bb41283056536d7af11e994ba4f9db81                    False
# ea91e47cac68b132887d7fc1175e91c2                    False
# bec784ef794cf596dbe2cbbaf5427ef0                    False
# 171e0bcea390c17fd70e3ffa6c2cd187                    False
# a60ebb7803c6a31795de3f8949cb6f98                    False
#
#                                                                         description  \
# uniq_id
# bb41283056536d7af11e994ba4f9db81  Glus Wedding Lingerie Set - Buy Turquoise Glus...
# ea91e47cac68b132887d7fc1175e91c2  Veelys Shiny White Quad Roller Skates - Size 4...
# bec784ef794cf596dbe2cbbaf5427ef0  Buy Bulaky vanity case Jewellery Vanity Case f...
# 171e0bcea390c17fd70e3ffa6c2cd187  FDT Women's Leggings - Buy Parrot Green FDT Wo...
# a60ebb7803c6a31795de3f8949cb6f98  Madcaps C38GR30 Men's Cargos - Buy Green Madca...
#
#                                   product_rating  overall_rating brand  \
# uniq_id
# bb41283056536d7af11e994ba4f9db81             NaN             NaN   NaN
# ea91e47cac68b132887d7fc1175e91c2             NaN             NaN   NaN
# bec784ef794cf596dbe2cbbaf5427ef0             3.0             3.0   NaN
# 171e0bcea390c17fd70e3ffa6c2cd187             NaN             NaN   NaN
# a60ebb7803c6a31795de3f8949cb6f98             NaN             NaN   NaN
#
#                                                              product_specifications
# uniq_id
# bb41283056536d7af11e994ba4f9db81  {"product_specification"=>[{"key"=>"Number of ...
# ea91e47cac68b132887d7fc1175e91c2  {"product_specification"=>[{"key"=>"Playing Le...
# bec784ef794cf596dbe2cbbaf5427ef0  {"product_specification"=>{"key"=>"Body Materi...
# 171e0bcea390c17fd70e3ffa6c2cd187  {"product_specification"=>[{"key"=>"Number of ...
# a60ebb7803c6a31795de3f8949cb6f98  {"product_specification"=>[{"key"=>"Number of ...

# %%
import numpy as np
import json
my_ser=flipkart_df['brand'].isnull()
clean_series=flipkart_df.loc[my_ser,'product_name'].str.split().str[0]
flipkart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19998 entries, c2d766ca982eca8304150849735ffef9 to cb4fa87a874f715fff567f7b7b3be79c
# Data columns (total 14 columns):
# crawl_timestamp            19998 non-null datetime64[ns]
# product_url                19998 non-null object
# product_name               19998 non-null category
# product_category_tree      19998 non-null category
# pid                        19998 non-null object
# retail_price               19920 non-null float64
# discounted_price           19920 non-null float64
# image                      19995 non-null object
# is_FK_Advantage_product    19998 non-null bool
# description                19996 non-null object
# product_rating             1849 non-null float64
# overall_rating             1849 non-null float64
# brand                      14134 non-null object
# product_specifications     19984 non-null object
# dtypes: bool(1), category(2), datetime64[ns](1), float64(4), object(6)
# memory usage: 3.3+ MB

# %%
flipkart_df['brand']=[str(k).split()[0] if v is np.NaN else k for k,v in zip(flipkart_df['product_name'],flipkart_df['brand'])]

# %%
flipkart_df[flipkart_df.brand.isnull()].head()
# Out:
# Empty DataFrame
# Columns: [crawl_timestamp, product_url, product_name, product_category_tree, pid, retail_price, discounted_price, image, is_FK_Advantage_product, description, product_rating, overall_rating, brand, product_specifications]
# Index: []

# %% [markdown]
# # product_specification

# %%
flipkart_df.product_specifications[0]
# Out:
# '{"product_specification"=>[{"key"=>"Number of Contents in Sales Package", "value"=>"Pack of 3"}, {"key"=>"Fabric", "value"=>"Cotton Lycra"}, {"key"=>"Type", "value"=>"Cycling Shorts"}, {"key"=>"Pattern", "value"=>"Solid"}, {"key"=>"Ideal For", "value"=>"Women\'s"}, {"value"=>"Gentle Machine Wash in Lukewarm Water, Do Not Bleach"}, {"key"=>"Style Code", "value"=>"ALTHT_3P_21"}, {"value"=>"3 shorts"}]}'

# %%
#f={v:{i.get('key'):i['value']}
d={}
for v,k in zip(flipkart_df['pid'],flipkart_df['product_specifications'].str.replace('=>',':')) :
    d = json.load(k.astype(str))
    for n in d.items():
        print(v,n)
#         d={i.get('key'):i.get('value') for i in n}
print(type(d))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-527-38835d1d8d2a> in <module>
#       2 d={}
#       3 for v,k in zip(flipkart_df['pid'],flipkart_df['product_specifications'].str.replace('=>',':')) :
# ----> 4     d = json.load(k.astype(str))
#       5     for n in d.items():
#       6         print(v,n)
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
f={v:n for v,k in zip(flipkart_df['pid'],flipkart_df['product_specifications'].str.replace('=>',':'))  for m,n in json.loads(k).items()}
#pd.DataFrame(f,index=flipkart_df['pid']).head()
f

# %%
my_dict = {"product_specification":[
    {"key":"Number of Contents in Sales Package", "value":"Pack of 3"}, 
    {"key":"Fabric", "value":"Cotton Lycra"}, 
    {"key":"Type", "value":"Cycling Shorts"}, 
    {"key":"Pattern", "value":"Solid"}, 
    {"key":"Ideal For", "value":"Women's"}, 
    {"value":"Gentle Machine Wash in Lukewarm Water, Do Not Bleach"}, 
    {"key":"Style Code", "value":"ALTHT_3P_21"}, 
    {"value":"3 shorts"}]}
print(my_dict['product_specification'])

# %%
flipkart_df.product_specifications.str.replace('{"product_specification"=>','').str.split('}')[0]

# %%
from pandas.io.json import json_normalize
json_normalize(flipkart_df.product_specifications[0].replace('=>',':'))
